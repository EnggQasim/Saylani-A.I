# %%
import numpy as np

# %%
# !cat salah.csv
# Out:
# UAL_ID	USER_ID	LOG_DATE	SESSION_ID	ACTIVITY_CODE	DESCRIPTION
# 1359513261	4036707	9/28/2018 10:36:24 AM	12811737	42802	Mobile App: Token Verified At Login: Success
# 1359513263	4036707	9/28/2018 10:36:24 AM	12811737	10171	Mobile:Transactions List Success
# 1359513262	4036707	9/28/2018 10:36:24 AM	12811737	60181	DisplayGetLastDrCrTransHistory
# 1359513230	4036707	9/28/2018 10:36:23 AM	12811737	60102	RefreshAcct
# 1359513229	4036707	9/28/2018 10:36:23 AM	12811737	42802	Mobile App: Token Verified At Login: Success
# 1359513036	4036707	9/28/2018 10:36:14 AM	12811737	10171	Mobile:Transactions List Success
# 1359513034	4036707	9/28/2018 10:36:14 AM	12811737	60108	GetBillData
# 1359513032	4036707	9/28/2018 10:36:14 AM	12811737	42802	Mobile App: Token Verified At Login: Success
# 1359512912	4036707	9/28/2018 10:36:09 AM	12811737	10171	Mobile:Transactions List Success
# 1359512911	4036707	9/28/2018 10:36:09 AM	12811737	60108	GetBillData
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("salah.csv")

# %%
df.head(2)
# Out:
#   UAL_ID\tUSER_ID\tLOG_DATE\tSESSION_ID\tACTIVITY_CODE\tDESCRIPTION
# 0  1359513261\t4036707\t9/28/2018 10:36:24 AM\t12...
# 1  1359513263\t4036707\t9/28/2018 10:36:24 AM\t12...

# %%
df=pd.read_csv("salah.csv", sep='\t')
df.head(2)
# Out:
#        UAL_ID  USER_ID               LOG_DATE SESSION_ID  ACTIVITY_CODE  \
# 0  1359513261  4036707  9/28/2018 10:36:24 AM   12811737          42802
# 1  1359513263  4036707  9/28/2018 10:36:24 AM   12811737          10171
#
#                                     DESCRIPTION
# 0  Mobile App: Token Verified At Login: Success
# 1              Mobile:Transactions List Success

# %%
df=pd.read_csv('ex.csv', sep=',')
df.head()
# Out:
#    1   2   3   4  hello
# 0  5   6   7   8  world
# 1  9  10  11  12    foo

# %%
pd.read_csv('ex.csv', names=['a', 'b', 'c', 'd', 'message'])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
names = ['a', 'b', 'c', 'd', 'message']
pd.read_csv('ex.csv', names=names, index_col='message')
# Out:
#          a   b   c   d
# message
# hello    1   2   3   4
# world    5   6   7   8
# foo      9  10  11  12

# %%
# !cat examples/csv_mindex.csv
# Out:
# key1,key2,value1,value2
# one,a,1,2
# one,b,3,4
# one,c,5,6
# one,d,7,8
# two,a,9,10
# two,b,11,12
# two,c,13,14
# two,d,15,16

# %%
parsed = pd.read_csv('examples/csv_mindex.csv',index_col=['key1', 'key2'])

# %%
parsed
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
# !cat 'examples/ex3.txt'
# Out:
# [' A B C\n',
# 'aaa -0.264438 -1.026059 -0.619500\n',
# 'bbb 0.927272 0.302904 -0.032399\n',
# 'ccc -0.264273 -0.386314 -0.217601\n',
# 'ddd -0.871858 -0.348382 1.100491\n']

# %%
result = pd.read_table('examples/ex3.txt', sep='\s+')
result
# Out:
#      ['         A         B          C\n',
# 0  'aaa -0.264438 -1.026059  -0.619500\n',
# 1  'bbb  0.927272  0.302904  -0.032399\n',
# 2  'ccc -0.264273 -0.386314  -0.217601\n',
# 3  'ddd -0.871858 -0.348382   1.100491\n']

# %%
# !cat 'examples/ex4.csv'
# Out:
# # hey!
# a,b,c,d,message
# # just wanted to make things more difficult for you
# # who reads CSV files with computers, anyway?
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo

# %%
pd.read_csv('examples/ex4.csv', skiprows=[0, 2, 3])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
result = pd.read_csv('examples/ex5.csv')
result
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
pd.isnull(result)
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
result = pd.read_csv('examples/ex5.csv', na_values=['NULL'])
result
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
sentinels = {'message': ['foo', 'NA'], 'something': ['two']}
pd.read_csv('examples/ex5.csv', na_values=sentinels)
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       NaN  5   6   NaN   8   world
# 2     three  9  10  11.0  12     NaN

# %%
pd.options.display.max_rows = 10

# %%
result = pd.read_csv('salah.csv', sep='\t')

# %%
result
# Out:
#            UAL_ID  USER_ID               LOG_DATE SESSION_ID  ACTIVITY_CODE  \
# 0      1359513261  4036707  9/28/2018 10:36:24 AM   12811737          42802
# 1      1359513263  4036707  9/28/2018 10:36:24 AM   12811737          10171
# 2      1359513262  4036707  9/28/2018 10:36:24 AM   12811737          60181
# 3      1359513230  4036707  9/28/2018 10:36:23 AM   12811737          60102
# 4      1359513229  4036707  9/28/2018 10:36:23 AM   12811737          42802
# ...           ...      ...                    ...        ...            ...
# 12537   622023411  4036707   1/4/2017 10:01:13 AM       1190          30014
# 12538   622023370  4036707   1/4/2017 10:01:08 AM       1190          41543
# 12539   622023359  4036707   1/4/2017 10:01:07 AM       1190           1545
# 12540   622023361  4036707   1/4/2017 10:01:07 AM       1190          49024
# 12541   622022979  4036707   1/4/2017 10:00:47 AM       1190          41541
#
#                                           DESCRIPTION
# ...

# %%
pd.read_csv('salah.csv', sep='\t', nrows=5)
# Out:
#        UAL_ID  USER_ID               LOG_DATE  SESSION_ID  ACTIVITY_CODE  \
# 0  1359513261  4036707  9/28/2018 10:36:24 AM    12811737          42802
# 1  1359513263  4036707  9/28/2018 10:36:24 AM    12811737          10171
# 2  1359513262  4036707  9/28/2018 10:36:24 AM    12811737          60181
# 3  1359513230  4036707  9/28/2018 10:36:23 AM    12811737          60102
# 4  1359513229  4036707  9/28/2018 10:36:23 AM    12811737          42802
#
#                                     DESCRIPTION
# 0  Mobile App: Token Verified At Login: Success
# 1              Mobile:Transactions List Success
# 2                DisplayGetLastDrCrTransHistory
# 3                                   RefreshAcct
# 4  Mobile App: Token Verified At Login: Success

# %%
chunker = pd.read_csv('salah.csv', sep='\t', chunksize=25)
chunker

# %%
tot = pd.Series([])
for piece in chunker:
    tot = tot.add(piece['LOG_DATE'].value_counts(), fill_value=0)
tot = tot.sort_values(ascending=False)

# %%
tot[:4]
# Out:
# 7/28/2017 9:34:32 AM    12.0
# 3/26/2018 4:51:34 PM    11.0
# 7/28/2017 9:34:33 AM    11.0
# 8/24/2017 3:43:50 PM    11.0
# dtype: float64

# %%
data = pd.read_csv('examples/ex5.csv')
data
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
import sys
data.to_csv(sys.stdout, sep='|')
# Out:
# |something|a|b|c|d|message
# 0|one|1|2|3.0|4|
# 1|two|5|6||8|world
# 2|three|9|10|11.0|12|foo

# %%
data.to_csv(sys.stdout, na_rep='NULL')
# Out:
# ,something,a,b,c,d,message
# 0,one,1,2,3.0,4,NULL
# 1,two,5,6,NULL,8,world
# 2,three,9,10,11.0,12,foo

# %%
sys.stdout

# %%
data.to_csv(sys.stdout, index=False, header=False)
# Out:
# one,1,2,3.0,4,
# two,5,6,,8,world
# three,9,10,11.0,12,foo

# %%
data.to_csv(sys.stdout, index=False, columns=['a', 'b', 'c'])
# Out:
# a,b,c
# 1,2,3.0
# 5,6,
# 9,10,11.0

# %%
 dates = pd.date_range('1/1/2000', periods=7)

# %%
ts = pd.Series(np.arange(7), index=dates)

# %%
ts.to_csv('examples/tseries.csv')
# !cat 'examples/tseries.csv'
# Out:
# 2000-01-01,0
# 2000-01-02,1
# 2000-01-03,2
# 2000-01-04,3
# 2000-01-05,4
# 2000-01-06,5
# 2000-01-07,6

# %%
# !cat 'examples/ex6.csv'
# Out:
# "a","b","c"
# "1","2","3"
# "1","2","3"

# %%
import csv
f = open('examples/ex6.csv')

# %%
reader = csv.reader(f)

# %%
reader

# %%
for line in reader:
    print(line)
""
# Out:
# ['a', 'b', 'c']
# ['1', '2', '3']
# ['1', '2', '3']
# ''

# %%
with open('examples/ex6.csv') as f:
    lines = list(csv.reader(f))

# %%
header, values = lines[0], lines[1:]

# %%
data_dict = {h: v for h, v in zip(header, zip(*values))}
data_dict
# Out:
# {'a': ('1', '1'), 'b': ('2', '2'), 'c': ('3', '3')}

# %%
f = open('examples/ex6.csv')

# %%
class my_dialect(csv.Dialect):
    lineterminator = '\n'
    delimiter = ';'
    quotechar = '"'
    quoting = csv.QUOTE_MINIMAL
    
reader = csv.reader(f, dialect=my_dialect)

# %%
eader = csv.reader(f, delimiter='|')

# %%
with open('mydata.csv', 'w') as f:
    writer = csv.writer(f, dialect=my_dialect)
    writer.writerow(('one', 'two', 'three'))
    writer.writerow(('1', '2', '3'))
    writer.writerow(('4', '5', '6'))
    writer.writerow(('7', '8', '9'))

# %%
obj = """
{"name": "Wes",
 "places_lived": ["United States", "Spain", "Germany"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
 {"name": "Katie", "age": 38,
 "pets": ["Sixes", "Stache", "Cisco"]}]
}
"""

# %%
import json

# %%
result = json.loads(obj)
result
# Out:
# {'name': 'Wes',
#  'pet': None,
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'siblings': [{'age': 30, 'name': 'Scott', 'pets': ['Zeus', 'Zuko']},
#   {'age': 38, 'name': 'Katie', 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
asjson = json.dumps(result)

# %%
asjson
# Out:
# '{"name": "Wes", "places_lived": ["United States", "Spain", "Germany"], "pet": null, "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]}, {"name": "Katie", "age": 38, "pets": ["Sixes", "Stache", "Cisco"]}]}'

# %%
siblings = pd.DataFrame(result['siblings'], columns=['name', 'age'])

# %%
siblings
# Out:
#     name  age
# 0  Scott   30
# 1  Katie   38

# %%
# !cat examples/example.json
# Out:
# [{"a": 1, "b": 2, "c": 3},
# {"a": 4, "b": 5, "c": 6},
# {"a": 7, "b": 8, "c": 9}]

# %%
data = pd.read_json('examples/example.json')
data
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
print(data.to_json())
# Out:
# {"a":{"0":1,"1":4,"2":7},"b":{"0":2,"1":5,"2":8},"c":{"0":3,"1":6,"2":9}}

# %%
print(data.to_json(orient='records'))
# Out:
# [{"a":1,"b":2,"c":3},{"a":4,"b":5,"c":6},{"a":7,"b":8,"c":9}]

# %%
data=pd.read_csv('salah.csv', sep='\t')
data.head()
# Out:
#        UAL_ID  USER_ID               LOG_DATE SESSION_ID  ACTIVITY_CODE  \
# 0  1359513261  4036707  9/28/2018 10:36:24 AM   12811737          42802
# 1  1359513263  4036707  9/28/2018 10:36:24 AM   12811737          10171
# 2  1359513262  4036707  9/28/2018 10:36:24 AM   12811737          60181
# 3  1359513230  4036707  9/28/2018 10:36:23 AM   12811737          60102
# 4  1359513229  4036707  9/28/2018 10:36:23 AM   12811737          42802
#
#                                     DESCRIPTION
# 0  Mobile App: Token Verified At Login: Success
# 1              Mobile:Transactions List Success
# 2                DisplayGetLastDrCrTransHistory
# 3                                   RefreshAcct
# 4  Mobile App: Token Verified At Login: Success

# %%
data.LOG_DATE=pd.to_datetime(data.LOG_DATE)

# %%
data.head()
# Out:
#        UAL_ID  USER_ID            LOG_DATE SESSION_ID  ACTIVITY_CODE  \
# 0  1359513261  4036707 2018-09-28 10:36:24   12811737          42802
# 1  1359513263  4036707 2018-09-28 10:36:24   12811737          10171
# 2  1359513262  4036707 2018-09-28 10:36:24   12811737          60181
# 3  1359513230  4036707 2018-09-28 10:36:23   12811737          60102
# 4  1359513229  4036707 2018-09-28 10:36:23   12811737          42802
#
#                                     DESCRIPTION
# 0  Mobile App: Token Verified At Login: Success
# 1              Mobile:Transactions List Success
# 2                DisplayGetLastDrCrTransHistory
# 3                                   RefreshAcct
# 4  Mobile App: Token Verified At Login: Success

# %%
data.dtypes
# Out:
# UAL_ID                    int64
# USER_ID                   int64
# LOG_DATE         datetime64[ns]
# SESSION_ID               object
# ACTIVITY_CODE             int64
# DESCRIPTION              object
# dtype: object

# %%
data.LOG_DATE.dt.month.value_counts()
# Out:
# 9     1361
# 1     1278
# 6     1266
# 8     1230
# 3     1223
#       ...
# 5      976
# 11     848
# 12     833
# 10     667
# 2      667
# Name: LOG_DATE, Length: 12, dtype: int64

# %%
from lxml import objectify
path = 'examples/mta_perf/Performance_MNR.xml'
parsed = objectify.parse(open(path))
root = parsed.getroot()

# %%
data = []
skip_fields = ['PARENT_SEQ', 'INDICATOR_SEQ',
               'DESIRED_CHANGE', 'DECIMAL_PLACES']

# %%
tables = pd.read_html('examples/FDIC_ Failed Bank List.html')

# %%
len(tables)
# Out:
# 1

# %%
failures = tables[0]
failures.head()
# Out:
#                                            Bank Name         City  ST   CERT  \
# 0                Washington Federal Bank for Savings      Chicago  IL  30570
# 1    The Farmers and Merchants State Bank of Argonia      Argonia  KS  17719
# 2                                Fayette County Bank   Saint Elmo  IL   1802
# 3  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI  30003
# 4                                     First NBC Bank  New Orleans  LA  58302
#
#                  Acquiring Institution       Closing Date       Updated Date
# 0                   Royal Savings Bank  December 15, 2017  February 21, 2018
# 1                          Conway Bank   October 13, 2017  February 21, 2018
# 2            United Fidelity Bank, fsb       May 26, 2017      July 26, 2017
# 3  First-Citizens Bank & Trust Company        May 5, 2017     March 22, 2018
# 4                         Whitney Bank     April 28, 2017   December 5, 2017

# %%
close_timestamps = pd.to_datetime(failures['Closing Date'])

# %%
close_timestamps.dt.year.value_counts()
# Out:
# 2015    8
# 2017    8
# 2016    5
# 2014    4
# Name: Closing Date, dtype: int64

# %%
for elt in root.INDICATOR_SEQ:
    el_data = {}
    for child in elt.getchildren():
        if child.tag in skip_fields:
            continue
        el_data[child.tag] = child.pyval
    data.append(el_data)

# %%
perf = pd.DataFrame(data)

# %%
from io import StringIO

# %%
tag = '<a href="http://www.google.com">Google</a>'
root = objectify.parse(StringIO(tag)).getroot()

# %%
root
# Out:
# <Element a at 0x2566dacf448>

# %%
root.get('href')
# Out:
# 'http://www.google.com'

# %%
root.text
# Out:
# 'Google'

# %%
frame = pd.read_csv('examples/ex.csv')
frame
# Out:
#    1   2   3   4  hello
# 0  5   6   7   8  world
# 1  9  10  11  12    foo

# %%
frame.to_pickle('examples/frame_pickle')

# %%
 pd.read_pickle('examples/frame_pickle')
# Out:
#    1   2   3   4  hello
# 0  5   6   7   8  world
# 1  9  10  11  12    foo

# %%
frame = pd.DataFrame({'a': np.random.randn(100)})
store = pd.HDFStore('mydata.h5')
store['obj1'] = frame
store['obj1_col'] = frame['a']
store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: mydata.h5

# %%
store['obj1']
# Out:
#            a
# 0  -0.027023
# 1   0.374394
# 2  -1.459069
# 3  -0.343515
# 4  -1.660113
# ..       ...
# 95 -0.820638
# 96  1.127620
# 97 -0.617626
# 98  0.889697
# 99  0.007480
#
# [100 rows x 1 columns]

# %%
store.put('obj2', frame, format='table')
store.select('obj2', where=['index >= 10 and index <= 15'])
# Out:
#            a
# 10  0.809654
# 11 -0.536072
# 12 -1.262039
# 13 -0.867112
# 14 -0.559745
# 15  0.257948

# %%
store.close()

# %%
frame.to_hdf('mydata.h5', 'obj3', format='table')

# %%
pd.read_hdf('mydata.h5', 'obj3', where=['index < 5'])
# Out:
#           a
# 0 -0.027023
# 1  0.374394
# 2 -1.459069
# 3 -0.343515
# 4 -1.660113

# %%
xlsx = pd.ExcelFile('examples/ex1.xlsx')
 
pd.read_excel(xlsx, 'Sheet1')
# Out:
#    a  b  c   d   e
# 0  1  4  7  10  13
# 1  2  5  8  11  14
# 2  3  6  9  12  15

# %%
frame = pd.read_excel('examples/ex1.xlsx', 'Sheet1')
frame
# Out:
#    a  b  c   d   e
# 0  1  4  7  10  13
# 1  2  5  8  11  14
# 2  3  6  9  12  15

# %%
writer = pd.ExcelWriter('examples/ex2.xlsx')
frame.to_excel(writer, 'Sheet1')
writer.save()

# %%
frame.to_excel('examples/ex2.xlsx')

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()

# %%
data
# Out:
# [{'assignee': None,
#   'assignees': [],
#   'author_association': 'CONTRIBUTOR',
#   'body': '- [ ] closes #xxxx\r\n- [x] tests added / passed\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [ ] whatsnew entry\r\n\r\nAsserting a method always passes. For example ``assert df.agg`` always passes.\r\n\r\nBy making the monotonicity and uniqueness tests stricter (i.e. testing for actual True/False rather than truthy/Falsy values) I think we get better ensurance that some PR doesn\'t accidentally turn a property into a method.\r\n ',
#   'closed_at': None,
#   'comments': 1,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/23256/comments',
#   'created_at': '2018-10-20T19:24:39Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/23256/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/23256',
#   'id': 372244655,
#   'labels': [],
# ...

# %%
data[0]['title']
# Out:
# 'TST: stricter monotonicity/uniqueness tests'

# %%
issues = pd.DataFrame(data, columns=['number', 'title','labels', 'state'])

# %%
issues
# Out:
#     number                                              title  \
# 0    23256        TST: stricter monotonicity/uniqueness tests
# 1    23255                       ENH:Add EA types to read CSV
# 2    23254  read_fwf: encoding is ignored when memory_map ...
# 3    23253  datetimeindex.to_period not behaving as expect...
# 4    23252  ENH: Allow keep="all" in duplicated method (#2...
# ..     ...                                                ...
# 25   23226        Reindex error after df.loc + pd.pivot_table
# 26   23225  Pandas 0.23.4 reindexing multiindexed frame wi...
# 27   23224                      Support None in integer_array
# 28   23223               [WIP] Add basic ExtensionIndex class
# 29   23222  Resampling using `nunique` causes multi-level ...
#
#                                                labels state
# 0                                                  []  open
# 1                                                  []  open
# ...

# %%
import sqlite3

# %%
query = """
CREATE TABLE test
(a VARCHAR(20), b VARCHAR(20),
c REAL, d INTEGER
 );"""
con = sqlite3.connect('mydata.sqlite')

# %%
con.execute(query)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-103-3ee84edf4275> in <module>()
# ----> 1 con.execute(query)
#
# OperationalError: table test already exists

# %%
con.commit()

# %%
 data = [('Atlanta', 'Georgia', 1.25, 6),
         ('Tallahassee', 'Florida', 2.6, 3),
         ('Sacramento', 'California', 1.7, 5)]

stmt = "INSERT INTO test VALUES(?, ?, ?, ?)"
con.executemany(stmt, data)

# %%
con.commit()

# %%
cursor = con.execute('select * from test')
rows = cursor.fetchall()

# %%
rows
# Out:
# [('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5),
#  ('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5)]

# %%
cursor.description
# Out:
# (('a', None, None, None, None, None, None),
#  ('b', None, None, None, None, None, None),
#  ('c', None, None, None, None, None, None),
#  ('d', None, None, None, None, None, None))

# %%
pd.DataFrame(rows, columns=[x[0] for x in cursor.description])
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5
# 3      Atlanta     Georgia  1.25  6
# 4  Tallahassee     Florida  2.60  3
# 5   Sacramento  California  1.70  5

# %%
import sqlalchemy as sqla
db = sqla.create_engine('sqlite:///mydata.sqlite')
pd.read_sql('select * from test', db)
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5
# 3      Atlanta     Georgia  1.25  6
# 4  Tallahassee     Florida  2.60  3
# 5   Sacramento  California  1.70  5
